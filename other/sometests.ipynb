# %%
from numpy import genfromtxt
import matplotlib.pyplot as plt
import csv
import numpy as np

with open('results/eye_x.csv','r') as dest_f:
    data_iter = csv.reader(dest_f,delimiter = ',')
    data = [data for data in data_iter]
    
    
data_array = np.asarray(data[1:],dtype=np.float64)
plt.plot(data_array[1].T)

# %%
data_array
# Out:
# array([[-246.29675 , -244.72594 , -244.18764 , ...,  -27.136187,
#          -26.01182 ,  -25.735191],
#        [-244.5066  , -245.57483 , -247.57454 , ...,  -24.342276,
#          -20.048525,  -18.807156]], dtype=float32)
